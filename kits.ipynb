# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahzeb999/KidneyTumorSegmentation/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use ! to denote shell commands in Jupyter Notebook
# !git clone https://github.com/neheller/kits19
# Change to the kits19 directory
# !cd kits19
# Install the requirements for the project
# !pip install -r kits19/requirements.txt
# Use python3 to execute the get imaging script
# !python3 -m kits19.starter_code.get_imaging
# Out:
# Cloning into 'kits19'...
# remote: Enumerating objects: 1026, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 1026 (delta 6), reused 5 (delta 5), pack-reused 1017 (from 2)
# Receiving objects: 100% (1026/1026), 29.74 MiB | 47.88 MiB/s, done.
# Resolving deltas: 100% (470/470), done.
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from -r kits19/requirements.txt (line 1)) (11.1.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (from -r kits19/requirements.txt (line 2)) (5.3.2)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from -r kits19/requirements.txt (line 3)) (2.37.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from -r kits19/requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r kits19/requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel->-r kits19/requirements.txt (line 2)) (6.5.2)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from nibabel->-r kits19/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from nibabel->-r kits19/requirements.txt (line 2)) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel->-r kits19/requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->-r kits19/requirements.txt (line 4)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->-r kits19/requirements.txt (line 4)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->-r kits19/requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->-r kits19/requirements.txt (line 4)) (2025.1.31)
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/kits19/starter_code/get_imaging.py", line 35, in <module>
#     if not get_destination(i).exists():
#            ^^^^^^^^^^^^^^^^^^
#   File "/content/kits19/starter_code/get_imaging.py", line 20, in get_destination
#     destination.parent.mkdir()
#   File "/usr/lib/python3.11/pathlib.py", line 1116, in mkdir
#     os.mkdir(self, mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'data/case_00000'

# %%
import os

os.chdir('/content/drive/MyDrive/Kits')

# %%
cd kits19
# Out:
# /content/drive/MyDrive/Kits/kits19

# %%
from utils import plot_sample

# %%
import os
import glob
import cv2
import imageio
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from PIL import Image
from matplotlib.pyplot import figure

import cv2 as cv
import numpy as np
import math
import time
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate

# %%
import matplotlib.pyplot as plt

def vis_im(array_):
    array = np.rot90(np.array(array_), k=-1)
    return array

def plot_mask_slice(mask_slice, color_map='nipy_spectral'):
    fig = plt.figure(figsize=(6, 6), dpi=100)
    plt.imshow(vis_im(mask_slice), alpha=0.5, cmap=color_map)
    plt.title('Mask Slice')
    plt.axis('off')
    plt.show()

def plot_image(sample_slice):
    fig = plt.figure(figsize=(6, 6), dpi=100)
    plt.imshow(sample_slice, cmap='gray')
    plt.axis('off')
# Assuming you have 'sample_mask' and 'sample' variables defined
# and 'sample_mask' is a 3D array containing the mask data
# and 'sample' is the index of the slice to visualize

# %%
# Read NIfTI files
def read_nii(filepath):
    ct_scan = nib.load(filepath)
    array = ct_scan.get_fdata()
    array = np.rot90(np.array(array), k=1, axes=(0, 2))
    return array

# %%
final_df = pd.read_csv('/content/drive/MyDrive/Kits/kits19/final_df.csv')

# %%
final_df['dirname_input'] = final_df['dirname_input'].str.replace('\\', '/')

# Convert backslashes to forward slashes in the 'dirname_segmentation' column
final_df['dirname_segmentation'] = final_df['dirname_segmentation'].str.replace('\\', '/')
# Out:
# <ipython-input-10-a7a07cfcd7cc>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   final_df['dirname_input'] = final_df['dirname_input'].str.replace('\\', '/')
# <ipython-input-10-a7a07cfcd7cc>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   final_df['dirname_segmentation'] = final_df['dirname_segmentation'].str.replace('\\', '/')

# %%
final_df.head()
# Out:
#      dirname_input        filename dirname_segmentation         filename_seg
# 0  data/case_00000  imaging.nii.gz      data/case_00000  segmentation.nii.gz
# 1  data/case_00001  imaging.nii.gz      data/case_00001  segmentation.nii.gz
# 2  data/case_00002  imaging.nii.gz      data/case_00002  segmentation.nii.gz
# 3  data/case_00003  imaging.nii.gz      data/case_00003  segmentation.nii.gz
# 4  data/case_00004  imaging.nii.gz      data/case_00004  segmentation.nii.gz

# %%
sample = 0

sample_ct = read_nii(final_df.loc[sample, 'dirname_input'] + '/' + final_df.loc[sample, 'filename'])
sample_mask = read_nii(final_df.loc[sample, 'dirname_segmentation'] + '/' + final_df.loc[sample, 'filename_seg'])

print(f"CT SHAPE: {sample_ct.shape}\nMask Shape: {sample_mask.shape}")
# Out:
# CT SHAPE: (512, 512, 611)
# Mask Shape: (512, 512, 611)

# %%
def CropImageLeft(Image):
    crop_start_left = 90
    crop_start_right = 258
    crop_start_top = 225
    crop_start_bottom = 393
#crop_end = crop_start + 400
    cropped_image = Image[crop_start_top:crop_start_bottom, crop_start_left:crop_start_right]
    return cropped_image

def CropImageRight(Image):
    crop_start_left = 276
    crop_start_right = 444
    crop_start_top = 255
    crop_start_bottom = 423
#crop_end = crop_start + 400
    cropped_image = Image[crop_start_top:crop_start_bottom, crop_start_left:crop_start_right]
    return cropped_image

# %%
idx = 0
mask = read_nii(final_df.loc[idx, 'dirname_segmentation'] + '/' + final_df.loc[idx, 'filename_seg'])
mask_slice = vis_im(mask[..., 0])
Filter = CropImageLeft(mask_slice)

plot_image(Filter)
type(Filter)
# Out:
# numpy.ndarray

# %%
# Preprocessing functions

def normalize_image(image):
    return image / 255.0

def preprocess_mask(mask):
    return (mask).astype(np.float32)

def preprocess_input(image):
    image = normalize_image(image)
    return tf.expand_dims(image, axis=-1)

def preprocess_data(image, mask):
    image = preprocess_input(image)
    mask = preprocess_mask(mask)
    return image, mask

# %%
import os

# Define the directory paths for saving train images and masks
train_images_dir = "train_images_Left"
train_masks_dir = "train_masks_Left"

# Create the directories if they don't exist
os.makedirs(train_images_dir, exist_ok=True)
os.makedirs(train_masks_dir, exist_ok=True)

for idx in range(0,200,2):
    # idx = 20

    ct = read_nii(final_df.loc[idx, 'dirname_input'] + '/' + final_df.loc[idx, 'filename'])
    mask = read_nii(final_df.loc[idx, 'dirname_segmentation'] + '/' + final_df.loc[idx, 'filename_seg'])

    for sample in range(0, ct.shape[2],3):
        mask_slice = vis_im(mask[..., sample])
        mask_slice = CropImageLeft(mask_slice)

        if not np.array_equal(mask_slice, Filter):
            sample_slice = vis_im(ct[..., sample]).astype(np.float32)
            sample_slice = CropImageLeft(sample_slice)
            enhanced_image = sample_slice  # fuzzyenhancement(sample_slice)

            data = preprocess_data(enhanced_image, mask_slice)

            # Save the data as individual files in the train_images and train_masks directories
            image_filename = f"{idx}_sample_{sample}_image.npy"
            mask_filename = f"{idx}_sample_{sample}_mask.npy"

            image_filepath = os.path.join(train_images_dir, image_filename)
            mask_filepath = os.path.join(train_masks_dir, mask_filename)

            np.save(image_filepath, data[0])  # Save the image data
            np.save(mask_filepath, data[1])  # Save the mask data

# %%
import os

# Define the directory paths for saving train images and masks
train_images_dir = "/content/drive/MyDrive/Kits/kits19/train_images_Left"
train_masks_dir = "/content/drive/MyDrive/Kits/kits19/train_masks_Left"

def load_data(images_dir, masks_dir):
    image_filenames = os.listdir(images_dir)
    mask_filenames = os.listdir(masks_dir)

    # Sort the filenames to ensure corresponding images and masks match
    image_filenames.sort()
    mask_filenames.sort()

    images = []
    masks = []

    for img_file, mask_file in zip(image_filenames, mask_filenames):
        image = np.load(os.path.join(images_dir, img_file))
        mask = np.load(os.path.join(masks_dir, mask_file))

        # Perform any necessary preprocessing (e.g., normalization) here
        # ...

        images.append(image)
        masks.append(mask)

    return np.array(images), np.array(masks)

# Load and preprocess the data
images, masks = load_data(train_images_dir, train_masks_dir)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, concatenate

# Assuming your train_images and train_masks are numpy arrays with the shape (num_samples, height, width, num_channels)

# Define the number of classes for segmentation
num_classes = 3

# Define the input shape of the images (height, width, num_channels)
input_shape = (138, 138, 1)

# Scaled Dot-Product Attention Layer
def scaled_dot_product_attention(q, k, v):
    temp = tf.matmul(q, k, transpose_b=True)
    scale = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = temp / tf.math.sqrt(scale)
    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)
    output = tf.matmul(attention_weights, v)
    return output

# Self-Attention Block
def self_attention(input_tensor, filters):
    q = Conv2D(filters // 8, (1, 1))(input_tensor)
    k = Conv2D(filters // 8, (1, 1))(input_tensor)
    v = Conv2D(filters, (1, 1))(input_tensor)
    attention = scaled_dot_product_attention(q, k, v)
    return attention

# U-Net Model with Self-Attention
def unet_model(input_shape, num_classes):
    inputs = Input(input_shape)

    # Encoder
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    # Bridge with Self-Attention
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)
    attention_conv4 = self_attention(conv4, 512)

    # Decoder with Self-Attention
    up5 = tf.image.resize(attention_conv4, (conv3.shape[1], conv3.shape[2]), method='nearest')
    up5 = concatenate([up5, conv3], axis=-1)
    conv5 = Conv2D(256, 3, activation='relu', padding='same')(up5)
    conv5 = Conv2D(256, 3, activation='relu', padding='same')(conv5)
    attention_conv5 = self_attention(conv5, 256)

    up6 = tf.image.resize(attention_conv5, (conv2.shape[1], conv2.shape[2]), method='nearest')
    up6 = concatenate([up6, conv2], axis=-1)
    conv6 = Conv2D(128, 3, activation='relu', padding='same')(up6)
    conv6 = Conv2D(128, 3, activation='relu', padding='same')(conv6)
    attention_conv6 = self_attention(conv6, 128)

    up7 = tf.image.resize(attention_conv6, (conv1.shape[1], conv1.shape[2]), method='nearest')
    up7 = concatenate([up7, conv1], axis=-1)
    conv7 = Conv2D(64, 3, activation='relu', padding='same')(up7)
    conv7 = Conv2D(64, 3, activation='relu', padding='same')(conv7)
    attention_conv7 = self_attention(conv7, 64)

    # Output layer (3 classes for segmentation)
    outputs = Conv2D(num_classes, 1, activation='softmax')(attention_conv7)

    # Create and compile the model
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

# Create the U-Net model with Self-Attention
model = unet_model(input_shape, num_classes)

# Print the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 138, 138, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 138, 138, 64  640         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 138, 138, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 69, 69, 64)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 69, 69, 128)  73856       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 69, 69, 128)  147584      ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 34, 34, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 34, 34, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 34, 34, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 256)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 17, 17, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 17, 17, 512)  2359808     ['conv2d_6[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 17, 17, 64)   32832       ['conv2d_7[0][0]']
#
#  tf.compat.v1.shape (TFOpLambda  (4,)                0           ['conv2d_9[0][0]']
#  )
#
#  tf.__operators__.getitem (Slic  ()                  0           ['tf.compat.v1.shape[0][0]']
#  ingOpLambda)
#
#  conv2d_8 (Conv2D)              (None, 17, 17, 64)   32832       ['conv2d_7[0][0]']
#
#  tf.cast (TFOpLambda)           ()                   0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.linalg.matmul (TFOpLambda)  (None, 17, 17, 17)   0           ['conv2d_8[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  tf.math.sqrt (TFOpLambda)      ()                   0           ['tf.cast[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 17, 17, 17)   0           ['tf.linalg.matmul[0][0]',
#                                                                   'tf.math.sqrt[0][0]']
#
#  tf.nn.softmax (TFOpLambda)     (None, 17, 17, 17)   0           ['tf.math.truediv[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 17, 17, 512)  262656      ['conv2d_7[0][0]']
#
#  tf.linalg.matmul_1 (TFOpLambda  (None, 17, 17, 512)  0          ['tf.nn.softmax[0][0]',
#  )                                                                'conv2d_10[0][0]']
#
#  tf.image.resize (TFOpLambda)   (None, 34, 34, 512)  0           ['tf.linalg.matmul_1[0][0]']
#
#  concatenate (Concatenate)      (None, 34, 34, 768)  0           ['tf.image.resize[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 34, 34, 256)  1769728     ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 34, 34, 256)  590080      ['conv2d_11[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 34, 34, 32)   8224        ['conv2d_12[0][0]']
#
#  tf.compat.v1.shape_1 (TFOpLamb  (4,)                0           ['conv2d_14[0][0]']
#  da)
#
#  tf.__operators__.getitem_1 (Sl  ()                  0           ['tf.compat.v1.shape_1[0][0]']
#  icingOpLambda)
#
#  conv2d_13 (Conv2D)             (None, 34, 34, 32)   8224        ['conv2d_12[0][0]']
#
#  tf.cast_1 (TFOpLambda)         ()                   0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.linalg.matmul_2 (TFOpLambda  (None, 34, 34, 34)  0           ['conv2d_13[0][0]',
#  )                                                                'conv2d_14[0][0]']
#
#  tf.math.sqrt_1 (TFOpLambda)    ()                   0           ['tf.cast_1[0][0]']
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 34, 34, 34)  0           ['tf.linalg.matmul_2[0][0]',
#                                                                   'tf.math.sqrt_1[0][0]']
#
#  tf.nn.softmax_1 (TFOpLambda)   (None, 34, 34, 34)   0           ['tf.math.truediv_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 34, 34, 256)  65792       ['conv2d_12[0][0]']
#
#  tf.linalg.matmul_3 (TFOpLambda  (None, 34, 34, 256)  0          ['tf.nn.softmax_1[0][0]',
#  )                                                                'conv2d_15[0][0]']
#
#  tf.image.resize_1 (TFOpLambda)  (None, 69, 69, 256)  0          ['tf.linalg.matmul_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 69, 69, 384)  0           ['tf.image.resize_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 69, 69, 128)  442496      ['concatenate_1[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 69, 69, 128)  147584      ['conv2d_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 69, 69, 16)   2064        ['conv2d_17[0][0]']
#
#  tf.compat.v1.shape_2 (TFOpLamb  (4,)                0           ['conv2d_19[0][0]']
#  da)
#
#  tf.__operators__.getitem_2 (Sl  ()                  0           ['tf.compat.v1.shape_2[0][0]']
#  icingOpLambda)
#
#  conv2d_18 (Conv2D)             (None, 69, 69, 16)   2064        ['conv2d_17[0][0]']
#
#  tf.cast_2 (TFOpLambda)         ()                   0           ['tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.linalg.matmul_4 (TFOpLambda  (None, 69, 69, 69)  0           ['conv2d_18[0][0]',
#  )                                                                'conv2d_19[0][0]']
#
#  tf.math.sqrt_2 (TFOpLambda)    ()                   0           ['tf.cast_2[0][0]']
#
#  tf.math.truediv_2 (TFOpLambda)  (None, 69, 69, 69)  0           ['tf.linalg.matmul_4[0][0]',
#                                                                   'tf.math.sqrt_2[0][0]']
#
#  tf.nn.softmax_2 (TFOpLambda)   (None, 69, 69, 69)   0           ['tf.math.truediv_2[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 69, 69, 128)  16512       ['conv2d_17[0][0]']
#
#  tf.linalg.matmul_5 (TFOpLambda  (None, 69, 69, 128)  0          ['tf.nn.softmax_2[0][0]',
#  )                                                                'conv2d_20[0][0]']
#
#  tf.image.resize_2 (TFOpLambda)  (None, 138, 138, 12  0          ['tf.linalg.matmul_5[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 138, 138, 19  0           ['tf.image.resize_2[0][0]',
#                                 2)                                'conv2d_1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 138, 138, 64  110656      ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 138, 138, 64  36928       ['conv2d_21[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 138, 138, 8)  520         ['conv2d_22[0][0]']
#
#  tf.compat.v1.shape_3 (TFOpLamb  (4,)                0           ['conv2d_24[0][0]']
#  da)
#
#  tf.__operators__.getitem_3 (Sl  ()                  0           ['tf.compat.v1.shape_3[0][0]']
#  icingOpLambda)
#
#  conv2d_23 (Conv2D)             (None, 138, 138, 8)  520         ['conv2d_22[0][0]']
#
#  tf.cast_3 (TFOpLambda)         ()                   0           ['tf.__operators__.getitem_3[0][0
#                                                                  ]']
#
#  tf.linalg.matmul_6 (TFOpLambda  (None, 138, 138, 13  0          ['conv2d_23[0][0]',
#  )                              8)                                'conv2d_24[0][0]']
#
#  tf.math.sqrt_3 (TFOpLambda)    ()                   0           ['tf.cast_3[0][0]']
#
#  tf.math.truediv_3 (TFOpLambda)  (None, 138, 138, 13  0          ['tf.linalg.matmul_6[0][0]',
#                                 8)                                'tf.math.sqrt_3[0][0]']
#
#  tf.nn.softmax_3 (TFOpLambda)   (None, 138, 138, 13  0           ['tf.math.truediv_3[0][0]']
#                                 8)
#
#  conv2d_25 (Conv2D)             (None, 138, 138, 64  4160        ['conv2d_22[0][0]']
#                                 )
#
#  tf.linalg.matmul_7 (TFOpLambda  (None, 138, 138, 64  0          ['tf.nn.softmax_3[0][0]',
#  )                              )                                 'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 138, 138, 3)  195         ['tf.linalg.matmul_7[0][0]']
#
# ==================================================================================================
# Total params: 8,218,291
# Trainable params: 8,218,291
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf

# Replace 'path_to_model_directory' with the actual path where your model is saved
model_directory = '/content/drive/MyDrive/Kits/kits19/model_L.h5'

# Load the model from the specified directory
model = tf.keras.models.load_model(model_directory)

# %%
predicted_masks = np.argmax(model.predict(images), axis=-1)
# Out:
# 65/65 [==============================] - 36s 345ms/step

# %%
import numpy as np

def dice_coefficient(predicted_mask, ground_truth_mask, class_label):
    # Create binary masks for the predicted and ground truth masks based on the class label
    binary_predicted_mask = (predicted_mask == class_label).astype(np.float32)
    binary_ground_truth_mask = (ground_truth_mask == class_label).astype(np.float32)

    # Check if the shapes of the binary masks match
    if binary_predicted_mask.shape != binary_ground_truth_mask.shape:
        raise ValueError("Predicted mask and ground truth mask must have the same shape.")

    # Flatten the binary masks to 1D arrays
    predicted_flat = binary_predicted_mask.flatten()
    ground_truth_flat = binary_ground_truth_mask.flatten()

    # Compute the intersection, total pixels, and predicted pixels for the given class
    intersection = np.sum(predicted_flat * ground_truth_flat)
    total_pixels = np.sum(ground_truth_flat)
    predicted_pixels = np.sum(predicted_flat)

    # Calculate the Dice coefficient for the given class
    dice = 2.0 * intersection / (total_pixels + predicted_pixels + 1e-7)  # Add a small value to avoid division by zero

    return dice

def average_dice_score(images, ground_truth_masks, predicted_masks, class_label):
    total_dice = 0.0
    num_images = len(images)

    for i in range(num_images):
        image = images[i]
        ground_truth_mask = ground_truth_masks[i]
        predicted_mask = predicted_masks[i]

        # Apply thresholding to the predicted mask
        thresholded_mask = predicted_mask

        dice = dice_coefficient(thresholded_mask, ground_truth_mask, class_label)
        total_dice += dice

    average_dice = total_dice / num_images
    return average_dice

# Example usage:
# Assuming you have lists of images, ground_truth_masks, and predicted_masks
# For simplicity, I assume you have two lists of 5 images each
def Dice_score(images,ground_truth_masks,predicted_masks):

  # Calculate the average Dice score for class 1
  class_label = 1
  average_dice_class1 = average_dice_score(images, ground_truth_masks, predicted_masks, class_label)
  print(f"Average Dice score for Kidney: {average_dice_class1:.4f}")

  # Calculate the average Dice score for class 2 (change the class_label as needed)
  class_label = 2
  average_dice_class2 = average_dice_score(images, ground_truth_masks, predicted_masks, class_label)
  print(f"Average Dice score for Kidney Tumor: {average_dice_class2:.4f}")

# %%
print("Train Data")
Dice_score(images,masks,predicted_masks)
# Out:
# Train Data
# Average Dice score for Kidney: 0.9094
# Average Dice score for Kidney Tumor: 0.1004

# %%
del images
del masks

# %%
import os

# Define the directory paths for saving train images and masks
train_images_dir = "test_images_Left"
train_masks_dir = "test_masks_Left"

# Create the directories if they don't exist
os.makedirs(train_images_dir, exist_ok=True)
os.makedirs(train_masks_dir, exist_ok=True)

for idx in range(200,210):
    # idx = 20

    ct = read_nii(final_df.loc[idx, 'dirname_input'] + '/' + final_df.loc[idx, 'filename'])
    mask = read_nii(final_df.loc[idx, 'dirname_segmentation'] + '/' + final_df.loc[idx, 'filename_seg'])

    for sample in range(0, ct.shape[2],3):
        mask_slice = vis_im(mask[..., sample])
        mask_slice = CropImageLeft(mask_slice)

        if not np.array_equal(mask_slice, Filter):
            sample_slice = vis_im(ct[..., sample]).astype(np.float32)
            sample_slice = CropImageLeft(sample_slice)
            enhanced_image = sample_slice  # fuzzyenhancement(sample_slice)

            data = preprocess_data(enhanced_image, mask_slice)

            # Save the data as individual files in the train_images and train_masks directories
            image_filename = f"{idx}_sample_{sample}_image.npy"
            mask_filename = f"{idx}_sample_{sample}_mask.npy"

            image_filepath = os.path.join(train_images_dir, image_filename)
            mask_filepath = os.path.join(train_masks_dir, mask_filename)

            np.save(image_filepath, data[0])  # Save the image data
            np.save(mask_filepath, data[1])  # Save the mask data

# %%
import os

# Define the directory paths for saving train images and masks
test_images_dir = "/content/drive/MyDrive/Kits/kits19/test_images_Left"
test_masks_dir = "/content/drive/MyDrive/Kits/kits19/test_masks_Left"

def load_data(images_dir, masks_dir):
    image_filenames = os.listdir(images_dir)
    mask_filenames = os.listdir(masks_dir)

    # Sort the filenames to ensure corresponding images and masks match
    image_filenames.sort()
    mask_filenames.sort()

    images = []
    masks = []

    for img_file, mask_file in zip(image_filenames, mask_filenames):
        image = np.load(os.path.join(images_dir, img_file))
        mask = np.load(os.path.join(masks_dir, mask_file))

        # Perform any necessary preprocessing (e.g., normalization) here
        # ...

        images.append(image)
        masks.append(mask)

    return np.array(images), np.array(masks)

# Load and preprocess the data
test_images, test_masks = load_data(test_images_dir, test_masks_dir)

# %%
test_masks.shape
# Out:
# (119, 168, 168)

# %%
test_images.shape
# Out:
# (119, 168, 168, 1)

# %%
predicted_masks_test = np.argmax(model.predict(test_images), axis=-1)
# Out:
# 4/4 [==============================] - 23s 2s/step

# %%
print("Test Data")
Dice_score(test_images,test_masks,predicted_masks_test)
# Out:
# Test Data
# Average Dice score for Kidney: 0.9097
# Average Dice score for Kidney Tumor: 0.0172

# %%
def visualize_segmentation(images, model, original_masks):
    # Predict masks for the test images
    predicted_masks = model.predict(images)

    # Convert the predicted masks to class labels (0, 1, 2, etc.) by taking the argmax
    predicted_labels = np.argmax(predicted_masks, axis=-1)

    # Visualize the segmentation
    num_samples = images.shape[0]
    for i in range(num_samples):
        plt.figure(figsize=(15, 5))

        # Original image
        plt.subplot(1, 4, 1)
        plt.imshow(images[i], cmap='gray')
        plt.title('Original Image')
        plt.axis('off')

        # Predicted mask
        plt.subplot(1, 4, 2)
        plt.imshow(predicted_labels[i], cmap='jet')  # Using 'jet' colormap for visualization
        plt.title('Predicted Mask')
        plt.axis('off')

        # Overlay the predicted mask on the original image
        plt.subplot(1, 4, 3)
        plt.imshow(images[i], cmap='gray')
        plt.imshow(predicted_labels[i], alpha=0.5, cmap='jet')
        plt.title('Overlay (Predicted)')
        plt.axis('off')

        # Original mask
        if original_masks is not None:

            plt.subplot(1, 4, 4)
            plt.imshow(original_masks[i], cmap='cool')
            plt.title('Original Mask')
            plt.axis('off')

        plt.show()

# %%
indexes = []
for i in range(100):
  if len(np.unique(test_masks[i]))==3:
    indexes.append(i)

# %%
visualize_segmentation(test_images[indexes], model,test_masks[indexes])
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
import os

# Define the directory paths for saving train images and masks
train_images_dir = "train_images_Right"
train_masks_dir = "train_masks_Right"

# Create the directories if they don't exist
os.makedirs(train_images_dir, exist_ok=True)
os.makedirs(train_masks_dir, exist_ok=True)

for idx in range(0,200,2):
    # idx = 20

    ct = read_nii(final_df.loc[idx, 'dirname_input'] + '/' + final_df.loc[idx, 'filename'])
    mask = read_nii(final_df.loc[idx, 'dirname_segmentation'] + '/' + final_df.loc[idx, 'filename_seg'])

    for sample in range(0, ct.shape[2],3):
        mask_slice = vis_im(mask[..., sample])
        mask_slice = CropImageRight(mask_slice)

        if not np.array_equal(mask_slice, Filter):
            sample_slice = vis_im(ct[..., sample]).astype(np.float32)
            sample_slice = CropImageRight(sample_slice)
            enhanced_image = sample_slice  # fuzzyenhancement(sample_slice)

            data = preprocess_data(enhanced_image, mask_slice)

            # Save the data as individual files in the train_images and train_masks directories
            image_filename = f"{idx}_sample_{sample}_image.npy"
            mask_filename = f"{idx}_sample_{sample}_mask.npy"

            image_filepath = os.path.join(train_images_dir, image_filename)
            mask_filepath = os.path.join(train_masks_dir, mask_filename)

            np.save(image_filepath, data[0])  # Save the image data
            np.save(mask_filepath, data[1])  # Save the mask data

# %%
import os

# Define the directory paths for saving train images and masks
train_images_dir = "/content/drive/MyDrive/Kits/kits19/train_images_Right"
train_masks_dir = "/content/drive/MyDrive/Kits/kits19/train_masks_Right"

def load_data(images_dir, masks_dir):
    image_filenames = os.listdir(images_dir)
    mask_filenames = os.listdir(masks_dir)

    # Sort the filenames to ensure corresponding images and masks match
    image_filenames.sort()
    mask_filenames.sort()

    images = []
    masks = []

    for img_file, mask_file in zip(image_filenames, mask_filenames):
        image = np.load(os.path.join(images_dir, img_file))
        mask = np.load(os.path.join(masks_dir, mask_file))

        # Perform any necessary preprocessing (e.g., normalization) here
        # ...

        images.append(image)
        masks.append(mask)

    return np.array(images), np.array(masks)

# Load and preprocess the data
train_images, train_masks = load_data(train_images_dir, train_masks_dir)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, concatenate

# Assuming your train_images and train_masks are numpy arrays with the shape (num_samples, height, width, num_channels)

# Define the number of classes for segmentation
num_classes = 3

# Define the input shape of the images (height, width, num_channels)
input_shape = (168, 168, 1)

# Scaled Dot-Product Attention Layer
def scaled_dot_product_attention(q, k, v):
    temp = tf.matmul(q, k, transpose_b=True)
    scale = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = temp / tf.math.sqrt(scale)
    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)
    output = tf.matmul(attention_weights, v)
    return output

# Self-Attention Block
def self_attention(input_tensor, filters):
    q = Conv2D(filters // 8, (1, 1))(input_tensor)
    k = Conv2D(filters // 8, (1, 1))(input_tensor)
    v = Conv2D(filters, (1, 1))(input_tensor)
    attention = scaled_dot_product_attention(q, k, v)
    return attention

# U-Net Model with Self-Attention
def unet_model(input_shape, num_classes):
    inputs = Input(input_shape)

    # Encoder
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    # Bridge with Self-Attention
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)
    attention_conv4 = self_attention(conv4, 512)

    # Decoder with Self-Attention
    up5 = tf.image.resize(attention_conv4, (conv3.shape[1], conv3.shape[2]), method='nearest')
    up5 = concatenate([up5, conv3], axis=-1)
    conv5 = Conv2D(256, 3, activation='relu', padding='same')(up5)
    conv5 = Conv2D(256, 3, activation='relu', padding='same')(conv5)
    attention_conv5 = self_attention(conv5, 256)

    up6 = tf.image.resize(attention_conv5, (conv2.shape[1], conv2.shape[2]), method='nearest')
    up6 = concatenate([up6, conv2], axis=-1)
    conv6 = Conv2D(128, 3, activation='relu', padding='same')(up6)
    conv6 = Conv2D(128, 3, activation='relu', padding='same')(conv6)
    attention_conv6 = self_attention(conv6, 128)

    up7 = tf.image.resize(attention_conv6, (conv1.shape[1], conv1.shape[2]), method='nearest')
    up7 = concatenate([up7, conv1], axis=-1)
    conv7 = Conv2D(64, 3, activation='relu', padding='same')(up7)
    conv7 = Conv2D(64, 3, activation='relu', padding='same')(conv7)
    attention_conv7 = self_attention(conv7, 64)

    # Output layer (3 classes for segmentation)
    outputs = Conv2D(num_classes, 1, activation='softmax')(attention_conv7)

    # Create and compile the model
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

# Create the U-Net model with Self-Attention
model = unet_model(input_shape, num_classes)

# Print the model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 168, 168, 1  0           []
#                                 )]
#
#  conv2d_27 (Conv2D)             (None, 168, 168, 64  640         ['input_2[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 168, 168, 64  36928       ['conv2d_27[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 84, 84, 64)  0           ['conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 84, 84, 128)  73856       ['max_pooling2d_3[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 84, 84, 128)  147584      ['conv2d_29[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 42, 42, 128)  0          ['conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 42, 42, 256)  295168      ['max_pooling2d_4[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 42, 42, 256)  590080      ['conv2d_31[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 21, 21, 256)  0          ['conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 21, 21, 512)  1180160     ['max_pooling2d_5[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 21, 21, 512)  2359808     ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 21, 21, 64)   32832       ['conv2d_34[0][0]']
#
#  tf.compat.v1.shape_4 (TFOpLamb  (4,)                0           ['conv2d_36[0][0]']
#  da)
#
#  tf.__operators__.getitem_4 (Sl  ()                  0           ['tf.compat.v1.shape_4[0][0]']
#  icingOpLambda)
#
#  conv2d_35 (Conv2D)             (None, 21, 21, 64)   32832       ['conv2d_34[0][0]']
#
#  tf.cast_4 (TFOpLambda)         ()                   0           ['tf.__operators__.getitem_4[0][0
#                                                                  ]']
#
#  tf.linalg.matmul_8 (TFOpLambda  (None, 21, 21, 21)  0           ['conv2d_35[0][0]',
#  )                                                                'conv2d_36[0][0]']
#
#  tf.math.sqrt_4 (TFOpLambda)    ()                   0           ['tf.cast_4[0][0]']
#
#  tf.math.truediv_4 (TFOpLambda)  (None, 21, 21, 21)  0           ['tf.linalg.matmul_8[0][0]',
#                                                                   'tf.math.sqrt_4[0][0]']
#
#  tf.nn.softmax_4 (TFOpLambda)   (None, 21, 21, 21)   0           ['tf.math.truediv_4[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 21, 21, 512)  262656      ['conv2d_34[0][0]']
#
#  tf.linalg.matmul_9 (TFOpLambda  (None, 21, 21, 512)  0          ['tf.nn.softmax_4[0][0]',
#  )                                                                'conv2d_37[0][0]']
#
#  tf.image.resize_3 (TFOpLambda)  (None, 42, 42, 512)  0          ['tf.linalg.matmul_9[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 42, 42, 768)  0           ['tf.image.resize_3[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 42, 42, 256)  1769728     ['concatenate_3[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 42, 42, 256)  590080      ['conv2d_38[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 42, 42, 32)   8224        ['conv2d_39[0][0]']
#
#  tf.compat.v1.shape_5 (TFOpLamb  (4,)                0           ['conv2d_41[0][0]']
#  da)
#
#  tf.__operators__.getitem_5 (Sl  ()                  0           ['tf.compat.v1.shape_5[0][0]']
#  icingOpLambda)
#
#  conv2d_40 (Conv2D)             (None, 42, 42, 32)   8224        ['conv2d_39[0][0]']
#
#  tf.cast_5 (TFOpLambda)         ()                   0           ['tf.__operators__.getitem_5[0][0
#                                                                  ]']
#
#  tf.linalg.matmul_10 (TFOpLambd  (None, 42, 42, 42)  0           ['conv2d_40[0][0]',
#  a)                                                               'conv2d_41[0][0]']
#
#  tf.math.sqrt_5 (TFOpLambda)    ()                   0           ['tf.cast_5[0][0]']
#
#  tf.math.truediv_5 (TFOpLambda)  (None, 42, 42, 42)  0           ['tf.linalg.matmul_10[0][0]',
#                                                                   'tf.math.sqrt_5[0][0]']
#
#  tf.nn.softmax_5 (TFOpLambda)   (None, 42, 42, 42)   0           ['tf.math.truediv_5[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 42, 42, 256)  65792       ['conv2d_39[0][0]']
#
#  tf.linalg.matmul_11 (TFOpLambd  (None, 42, 42, 256)  0          ['tf.nn.softmax_5[0][0]',
#  a)                                                               'conv2d_42[0][0]']
#
#  tf.image.resize_4 (TFOpLambda)  (None, 84, 84, 256)  0          ['tf.linalg.matmul_11[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 84, 84, 384)  0           ['tf.image.resize_4[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 84, 84, 128)  442496      ['concatenate_4[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 84, 84, 128)  147584      ['conv2d_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 84, 84, 16)   2064        ['conv2d_44[0][0]']
#
#  tf.compat.v1.shape_6 (TFOpLamb  (4,)                0           ['conv2d_46[0][0]']
#  da)
#
#  tf.__operators__.getitem_6 (Sl  ()                  0           ['tf.compat.v1.shape_6[0][0]']
#  icingOpLambda)
#
#  conv2d_45 (Conv2D)             (None, 84, 84, 16)   2064        ['conv2d_44[0][0]']
#
#  tf.cast_6 (TFOpLambda)         ()                   0           ['tf.__operators__.getitem_6[0][0
#                                                                  ]']
#
#  tf.linalg.matmul_12 (TFOpLambd  (None, 84, 84, 84)  0           ['conv2d_45[0][0]',
#  a)                                                               'conv2d_46[0][0]']
#
#  tf.math.sqrt_6 (TFOpLambda)    ()                   0           ['tf.cast_6[0][0]']
#
#  tf.math.truediv_6 (TFOpLambda)  (None, 84, 84, 84)  0           ['tf.linalg.matmul_12[0][0]',
#                                                                   'tf.math.sqrt_6[0][0]']
#
#  tf.nn.softmax_6 (TFOpLambda)   (None, 84, 84, 84)   0           ['tf.math.truediv_6[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 84, 84, 128)  16512       ['conv2d_44[0][0]']
#
#  tf.linalg.matmul_13 (TFOpLambd  (None, 84, 84, 128)  0          ['tf.nn.softmax_6[0][0]',
#  a)                                                               'conv2d_47[0][0]']
#
#  tf.image.resize_5 (TFOpLambda)  (None, 168, 168, 12  0          ['tf.linalg.matmul_13[0][0]']
#                                 8)
#
#  concatenate_5 (Concatenate)    (None, 168, 168, 19  0           ['tf.image.resize_5[0][0]',
#                                 2)                                'conv2d_28[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 168, 168, 64  110656      ['concatenate_5[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 168, 168, 64  36928       ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_51 (Conv2D)             (None, 168, 168, 8)  520         ['conv2d_49[0][0]']
#
#  tf.compat.v1.shape_7 (TFOpLamb  (4,)                0           ['conv2d_51[0][0]']
#  da)
#
#  tf.__operators__.getitem_7 (Sl  ()                  0           ['tf.compat.v1.shape_7[0][0]']
#  icingOpLambda)
#
#  conv2d_50 (Conv2D)             (None, 168, 168, 8)  520         ['conv2d_49[0][0]']
#
#  tf.cast_7 (TFOpLambda)         ()                   0           ['tf.__operators__.getitem_7[0][0
#                                                                  ]']
#
#  tf.linalg.matmul_14 (TFOpLambd  (None, 168, 168, 16  0          ['conv2d_50[0][0]',
#  a)                             8)                                'conv2d_51[0][0]']
#
#  tf.math.sqrt_7 (TFOpLambda)    ()                   0           ['tf.cast_7[0][0]']
#
#  tf.math.truediv_7 (TFOpLambda)  (None, 168, 168, 16  0          ['tf.linalg.matmul_14[0][0]',
#                                 8)                                'tf.math.sqrt_7[0][0]']
#
#  tf.nn.softmax_7 (TFOpLambda)   (None, 168, 168, 16  0           ['tf.math.truediv_7[0][0]']
#                                 8)
#
#  conv2d_52 (Conv2D)             (None, 168, 168, 64  4160        ['conv2d_49[0][0]']
#                                 )
#
#  tf.linalg.matmul_15 (TFOpLambd  (None, 168, 168, 64  0          ['tf.nn.softmax_7[0][0]',
#  a)                             )                                 'conv2d_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 168, 168, 3)  195         ['tf.linalg.matmul_15[0][0]']
#
# ==================================================================================================
# Total params: 8,218,291
# Trainable params: 8,218,291
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 40

# Batch size for training
batch_size = 16

# Fit the model to the training data
model.fit(train_images, train_masks, batch_size=batch_size, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/40
# 109/109 [==============================] - 93s 533ms/step - loss: 0.4315 - accuracy: 0.8886 - val_loss: 0.4303 - val_accuracy: 0.8586
# Epoch 2/40
# 109/109 [==============================] - 46s 421ms/step - loss: 0.2720 - accuracy: 0.8928 - val_loss: 0.3168 - val_accuracy: 0.8586
# Epoch 3/40
# 109/109 [==============================] - 48s 438ms/step - loss: 0.2028 - accuracy: 0.9144 - val_loss: 0.3108 - val_accuracy: 0.8716
# Epoch 4/40
# 109/109 [==============================] - 46s 423ms/step - loss: 0.1762 - accuracy: 0.9291 - val_loss: 0.2617 - val_accuracy: 0.8912
# Epoch 5/40
# 109/109 [==============================] - 48s 438ms/step - loss: 0.1491 - accuracy: 0.9427 - val_loss: 0.2236 - val_accuracy: 0.9130
# Epoch 6/40
# 109/109 [==============================] - 48s 438ms/step - loss: 0.1231 - accuracy: 0.9559 - val_loss: 0.2093 - val_accuracy: 0.9198
# Epoch 7/40
# 109/109 [==============================] - 46s 424ms/step - loss: 0.1614 - accuracy: 0.9467 - val_loss: 0.2336 - val_accuracy: 0.9187
# Epoch 8/40
# 109/109 [==============================] - 46s 423ms/step - loss: 0.1021 - accuracy: 0.9662 - val_loss: 0.1690 - val_accuracy: 0.9428
# Epoch 9/40
# 109/109 [==============================] - 48s 438ms/step - loss: 0.0805 - accuracy: 0.9736 - val_loss: 0.1795 - val_accuracy: 0.9344
# Epoch 10/40
# 109/109 [==============================] - 48s 437ms/step - loss: 0.0740 - accuracy: 0.9761 - val_loss: 0.1592 - val_accuracy: 0.9439
# Epoch 11/40
# 109/109 [==============================] - 46s 423ms/step - loss: 0.0581 - accuracy: 0.9812 - val_loss: 0.1504 - val_accuracy: 0.9503
# Epoch 12/40
# 109/109 [==============================] - 48s 438ms/step - loss: 0.0576 - accuracy: 0.9813 - val_loss: 0.1714 - val_accuracy: 0.9497
# Epoch 13/40
# 109/109 [==============================] - 46s 424ms/step - loss: 0.0557 - accuracy: 0.9819 - val_loss: 0.1466 - val_accuracy: 0.9493
# Epoch 14/40
# 109/109 [==============================] - 47s 431ms/step - loss: 0.0454 - accuracy: 0.9850 - val_loss: 0.1337 - val_accuracy: 0.9555
# Epoch 15/40
# 109/109 [==============================] - 48s 439ms/step - loss: 0.0423 - accuracy: 0.9861 - val_loss: 0.1291 - val_accuracy: 0.9578
# Epoch 16/40
# 109/109 [==============================] - 48s 438ms/step - loss: 0.0538 - accuracy: 0.9829 - val_loss: 0.3945 - val_accuracy: 0.9074
# Epoch 17/40
# 109/109 [==============================] - 45s 417ms/step - loss: 6.5151 - accuracy: 0.8883 - val_loss: 0.4031 - val_accuracy: 0.8586
# Epoch 18/40
# 109/109 [==============================] - 47s 429ms/step - loss: 0.2870 - accuracy: 0.8954 - val_loss: 0.3262 - val_accuracy: 0.8735
# Epoch 19/40
# 109/109 [==============================] - 47s 430ms/step - loss: 0.2106 - accuracy: 0.9249 - val_loss: 0.2875 - val_accuracy: 0.8952
# Epoch 20/40
# 109/109 [==============================] - 47s 430ms/step - loss: 0.1750 - accuracy: 0.9379 - val_loss: 0.2829 - val_accuracy: 0.8918
# Epoch 21/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.1542 - accuracy: 0.9447 - val_loss: 0.2574 - val_accuracy: 0.9052
# Epoch 22/40
# 109/109 [==============================] - 47s 430ms/step - loss: 0.1379 - accuracy: 0.9510 - val_loss: 0.2645 - val_accuracy: 0.9056
# Epoch 23/40
# 109/109 [==============================] - 47s 430ms/step - loss: 0.1266 - accuracy: 0.9548 - val_loss: 0.2516 - val_accuracy: 0.9100
# Epoch 24/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.1222 - accuracy: 0.9565 - val_loss: 0.2413 - val_accuracy: 0.9152
# Epoch 25/40
# 109/109 [==============================] - 47s 430ms/step - loss: 0.1306 - accuracy: 0.9550 - val_loss: 0.2612 - val_accuracy: 0.9028
# Epoch 26/40
# 109/109 [==============================] - 47s 429ms/step - loss: 0.1209 - accuracy: 0.9574 - val_loss: 0.2392 - val_accuracy: 0.9163
# Epoch 27/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.1086 - accuracy: 0.9618 - val_loss: 0.2249 - val_accuracy: 0.9194
# Epoch 28/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.1034 - accuracy: 0.9636 - val_loss: 0.2374 - val_accuracy: 0.9183
# Epoch 29/40
# 109/109 [==============================] - 47s 429ms/step - loss: 0.0969 - accuracy: 0.9657 - val_loss: 0.2265 - val_accuracy: 0.9201
# Epoch 30/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.0935 - accuracy: 0.9670 - val_loss: 0.2068 - val_accuracy: 0.9230
# Epoch 31/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.0936 - accuracy: 0.9669 - val_loss: 0.2178 - val_accuracy: 0.9247
# Epoch 32/40
# 109/109 [==============================] - 47s 430ms/step - loss: 0.0908 - accuracy: 0.9678 - val_loss: 0.2277 - val_accuracy: 0.9251
# Epoch 33/40
# 109/109 [==============================] - 47s 431ms/step - loss: 0.0835 - accuracy: 0.9707 - val_loss: 0.2452 - val_accuracy: 0.9230
# Epoch 34/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.0788 - accuracy: 0.9721 - val_loss: 0.2210 - val_accuracy: 0.9274
# Epoch 35/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.0773 - accuracy: 0.9730 - val_loss: 0.2229 - val_accuracy: 0.9288
# Epoch 36/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.0727 - accuracy: 0.9743 - val_loss: 0.2379 - val_accuracy: 0.9271
# Epoch 37/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.0722 - accuracy: 0.9744 - val_loss: 0.2416 - val_accuracy: 0.9274
# Epoch 38/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.0690 - accuracy: 0.9757 - val_loss: 0.2712 - val_accuracy: 0.9273
# Epoch 39/40
# 109/109 [==============================] - 45s 415ms/step - loss: 0.0661 - accuracy: 0.9766 - val_loss: 0.2385 - val_accuracy: 0.9295
# Epoch 40/40
# 109/109 [==============================] - 45s 416ms/step - loss: 0.0646 - accuracy: 0.9771 - val_loss: 0.2444 - val_accuracy: 0.9313

# %%
model.save('model_R.h5')

# %%
predicted_masks = np.argmax(model.predict(train_images), axis=-1)
# Out:
# 68/68 [==============================] - 30s 343ms/step

# %%
import numpy as np

def dice_coefficient(predicted_mask, ground_truth_mask, class_label):
    # Create binary masks for the predicted and ground truth masks based on the class label
    binary_predicted_mask = (predicted_mask == class_label).astype(np.float32)
    binary_ground_truth_mask = (ground_truth_mask == class_label).astype(np.float32)

    # Check if the shapes of the binary masks match
    if binary_predicted_mask.shape != binary_ground_truth_mask.shape:
        raise ValueError("Predicted mask and ground truth mask must have the same shape.")

    # Flatten the binary masks to 1D arrays
    predicted_flat = binary_predicted_mask.flatten()
    ground_truth_flat = binary_ground_truth_mask.flatten()

    # Compute the intersection, total pixels, and predicted pixels for the given class
    intersection = np.sum(predicted_flat * ground_truth_flat)
    total_pixels = np.sum(ground_truth_flat)
    predicted_pixels = np.sum(predicted_flat)

    # Calculate the Dice coefficient for the given class
    dice = 2.0 * intersection / (total_pixels + predicted_pixels + 1e-7)  # Add a small value to avoid division by zero

    return dice

def average_dice_score(images, ground_truth_masks, predicted_masks, class_label):
    total_dice = 0.0
    num_images = len(images)

    for i in range(num_images):
        image = images[i]
        ground_truth_mask = ground_truth_masks[i]
        predicted_mask = predicted_masks[i]

        # Apply thresholding to the predicted mask
        thresholded_mask = predicted_mask

        dice = dice_coefficient(thresholded_mask, ground_truth_mask, class_label)
        total_dice += dice

    average_dice = total_dice / num_images
    return average_dice

# Example usage:
# Assuming you have lists of images, ground_truth_masks, and predicted_masks
# For simplicity, I assume you have two lists of 5 images each
def Dice_score(images,ground_truth_masks,predicted_masks):

  # Calculate the average Dice score for class 1
  class_label = 1
  average_dice_class1 = average_dice_score(images, ground_truth_masks, predicted_masks, class_label)
  print(f"Average Dice score for Kidney: {average_dice_class1:.4f}")

  # Calculate the average Dice score for class 2 (change the class_label as needed)
  class_label = 2
  average_dice_class2 = average_dice_score(images, ground_truth_masks, predicted_masks, class_label)
  print(f"Average Dice score for Kidney Tumor: {average_dice_class2:.4f}")

# %%
print("Train Data")
Dice_score(train_images,train_masks,predicted_masks)
# Out:
# Train Data
# Average Dice score for Kidney: 0.8026
# Average Dice score for Kidney Tumor: 0.0753

# %%
import tensorflow as tf

# Replace 'path_to_model_directory' with the actual path where your model is saved
model_directory = '/content/drive/MyDrive/Kits/kits19/model_R.h5'

# Load the model from the specified directory
model = tf.keras.models.load_model(model_directory)

# %%
import os

# Define the directory paths for saving train images and masks
train_images_dir = "test_images_Right"
train_masks_dir = "test_masks_Right"

# Create the directories if they don't exist
os.makedirs(train_images_dir, exist_ok=True)
os.makedirs(train_masks_dir, exist_ok=True)

for idx in range(200,210):
    # idx = 20

    ct = read_nii(final_df.loc[idx, 'dirname_input'] + '/' + final_df.loc[idx, 'filename'])
    mask = read_nii(final_df.loc[idx, 'dirname_segmentation'] + '/' + final_df.loc[idx, 'filename_seg'])

    for sample in range(0, ct.shape[2],3):
        mask_slice = vis_im(mask[..., sample])
        mask_slice = CropImageRight(mask_slice)

        if not np.array_equal(mask_slice, Filter):
            sample_slice = vis_im(ct[..., sample]).astype(np.float32)
            sample_slice = CropImageRight(sample_slice)
            enhanced_image = sample_slice  # fuzzyenhancement(sample_slice)

            data = preprocess_data(enhanced_image, mask_slice)

            # Save the data as individual files in the train_images and train_masks directories
            image_filename = f"{idx}_sample_{sample}_image.npy"
            mask_filename = f"{idx}_sample_{sample}_mask.npy"

            image_filepath = os.path.join(train_images_dir, image_filename)
            mask_filepath = os.path.join(train_masks_dir, mask_filename)

            np.save(image_filepath, data[0])  # Save the image data
            np.save(mask_filepath, data[1])  # Save the mask data

# %%
import os

# Define the directory paths for saving train images and masks
test_images_dir = "/content/drive/MyDrive/Kits/kits19/test_images_Right"
test_masks_dir = "/content/drive/MyDrive/Kits/kits19/test_masks_Right"

def load_data(images_dir, masks_dir):
    image_filenames = os.listdir(images_dir)
    mask_filenames = os.listdir(masks_dir)

    # Sort the filenames to ensure corresponding images and masks match
    image_filenames.sort()
    mask_filenames.sort()

    images = []
    masks = []

    for img_file, mask_file in zip(image_filenames, mask_filenames):
        image = np.load(os.path.join(images_dir, img_file))
        mask = np.load(os.path.join(masks_dir, mask_file))

        # Perform any necessary preprocessing (e.g., normalization) here
        # ...

        images.append(image)
        masks.append(mask)

    return np.array(images), np.array(masks)

# Load and preprocess the data
test_images, test_masks = load_data(test_images_dir, test_masks_dir)

# %%
test_masks.shape
# Out:
# (133, 168, 168)

# %%
test_images.shape
# Out:
# (133, 168, 168, 1)

# %%
predicted_masks_test = np.argmax(model.predict(test_images), axis=-1)
# Out:
# 5/5 [==============================] - 17s 606ms/step

# %%
print("Test Data")
Dice_score(test_images,test_masks,predicted_masks_test)
# Out:
# Test Data
# Average Dice score for Kidney: 0.7896
# Average Dice score for Kidney Tumor: 0.0212

# %%
def visualize_segmentation(images, model, original_masks):
    # Predict masks for the test images
    predicted_masks = model.predict(images)

    # Convert the predicted masks to class labels (0, 1, 2, etc.) by taking the argmax
    predicted_labels = np.argmax(predicted_masks, axis=-1)

    # Visualize the segmentation
    num_samples = images.shape[0]
    for i in range(num_samples):
        plt.figure(figsize=(15, 5))

        # Original image
        plt.subplot(1, 4, 1)
        plt.imshow(images[i], cmap='gray')
        plt.title('Original Image')
        plt.axis('off')

        # Predicted mask
        plt.subplot(1, 4, 2)
        plt.imshow(predicted_labels[i], cmap='jet')  # Using 'jet' colormap for visualization
        plt.title('Predicted Mask')
        plt.axis('off')

        # Overlay the predicted mask on the original image
        plt.subplot(1, 4, 3)
        plt.imshow(images[i], cmap='gray')
        plt.imshow(predicted_labels[i], alpha=0.5, cmap='jet')
        plt.title('Overlay (Predicted)')
        plt.axis('off')

        # Original mask
        if original_masks is not None:

            plt.subplot(1, 4, 4)
            plt.imshow(original_masks[i], cmap='cool')
            plt.title('Original Mask')
            plt.axis('off')

        plt.show()

# %%
indexes = []
for i in range(100):
  if len(np.unique(test_masks[i]))==3:
    indexes.append(i)

# %%
visualize_segmentation(test_images[indexes], model,test_masks[indexes])
# Out:
# 1/1 [==============================] - 6s 6s/step
